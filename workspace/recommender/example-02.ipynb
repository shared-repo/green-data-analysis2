# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv('data-files/tmdb-5000/tmdb_5000_movies.csv')
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
movies2 = \
    movies[['id', 'title', 'genres', 'keywords', 'overview', 'vote_average', 'vote_count', 'popularity']].copy()
movies2.head(2)
# Out:
#       id                                     title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
#
#                                             overview  vote_average  \
# 0  In the 22nd century, a paraplegic Marine is di...           7.2
# 1  Captain Barbossa, long believed to be dead, ha...           6.9
#
#    vote_count  popularity
# 0       11800  150.437577
# 1        4500  139.082615

# %%
import json

# genres, keywords 전처리 : 문자열의 내용에서 필요한 정보만 뽑기
print( type(movies2['genres'][0]) )

eval(movies2['genres'][0])          # 문자열 -> 객체
json.loads(movies2['genres'][0])    # 문자열 -> 객체
# Out:
# <class 'str'>
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]
