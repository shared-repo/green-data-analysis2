# %%
import requests

# %%
url = "https://sgisapi.kostat.go.kr/OpenAPI3/auth/authentication.json"
service_id = "40793583c7664887994c"
secret_key = "cacdb0696df84de5afed"
resp = requests.get(f'{url}?consumer_key={service_id}&consumer_secret={secret_key}')

# %%
import json

auth_info = json.loads(resp.content.decode('utf-8'))

# %%
auth_info
# Out:
# {'id': 'API_0101',
#  'result': {'accessTimeout': '1710309790943',
#   'accessToken': 'fdfe4b3e-0fb7-40e9-a340-bcfc436f6756'},
#  'errMsg': 'Success',
#  'errCd': 0,
#  'trId': '17X9_API_0101_1710295390853'}

# %%
url = "https://sgisapi.kostat.go.kr/OpenAPI3/boundary/hadmarea.geojson"
resp = requests.get(f"{url}?accessToken={auth_info['result']['accessToken']}&year=2023&adm_cd=11&low_search=1")

# %%
result = json.loads(resp.content.decode('utf-8'))

# %%
result.keys()
# Out:
# dict_keys(['type', 'id', 'errMsg', 'errCd', 'trId', 'features'])

# %%
result['features']
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[953651.3248999999, 1959043.1407999988],
#      [953671.9659000005, 1958970.5468000018],
#      [953780.2278999991, 1958976.7080000006],
#      [953976.8263999997, 1958998.1654000012],
#      [954074.465499999, 1958953.5649999988],
#      [954109.9588999995, 1958915.4666000004],
#      [954113.4221000002, 1958904.8203999996],
#      [954119.754899999, 1958885.3515999997],
#      [954084.7439000006, 1958668.7310000001],
#      [954193.5969000002, 1958564.448400001],
#      [954262.3775000005, 1958464.7484000006],
#      [954276.3601000006, 1958444.4798000003],
#      [954386.3774999995, 1958198.6758],
#      [954433.5564999986, 1958092.6023999993],
#      [954425.3119999997, 1958071.8268000002],
#      [954391.3987000004, 1957985.426799999],
#      [954389.2375000005, 1957880.251100001],
#      [954437.0755000003, 1957716.2024000015],
#      [954508.5431000008, 1957518.5467000003],
# ...
